# %%
# !python -V
# Out:
# Python 3.9.15

# %%
import pandas as pd

# %%
import pickle

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge

from sklearn.metrics import mean_squared_error

# %%
import mlflow


mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("nyc-taxi-experiment")
# Out:
# 2024/05/21 23:04:36 INFO mlflow.tracking.fluent: Experiment with name 'nyc-taxi-experiment' does not exist. Creating a new experiment.
# <Experiment: artifact_location='/Users/weishanhe/my_github/mlops-zoomcamp/02-experiment-tracking/mlruns/1', creation_time=1716347076037, experiment_id='1', last_update_time=1716347076037, lifecycle_stage='active', name='nyc-taxi-experiment', tags={}>

# %%
def read_dataframe(filename):
    df = pd.read_parquet(filename)

    df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
    df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)

    df['duration'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
    df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)

    df = df[(df.duration >= 1) & (df.duration <= 60)]

    categorical = ['PULocationID', 'DOLocationID']
    df[categorical] = df[categorical].astype(str)
    
    return df

# %%
df_train = read_dataframe('./data/green_tripdata_2021-01.parquet')
df_val = read_dataframe('./data/green_tripdata_2021-02.parquet')

# %%
len(df_train), len(df_val)
# Out:
# (73908, 61921)

# %%
df_train['PU_DO'] = df_train['PULocationID'] + '_' + df_train['DOLocationID']
df_val['PU_DO'] = df_val['PULocationID'] + '_' + df_val['DOLocationID']

# %%
categorical = ['PU_DO'] #'PULocationID', 'DOLocationID']
numerical = ['trip_distance']

dv = DictVectorizer()

train_dicts = df_train[categorical + numerical].to_dict(orient='records')
X_train = dv.fit_transform(train_dicts)

val_dicts = df_val[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dicts)

# %%
target = 'duration'
y_train = df_train[target].values
y_val = df_val[target].values

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_val)

mean_squared_error(y_val, y_pred, squared=False)
# Out:
# /Users/weishanhe/opt/miniconda3/envs/mlops/lib/python3.9/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# 7.758715208946364

# %%
with open('models/lin_reg.bin', 'wb') as f_out:
    pickle.dump((dv, lr), f_out)

# %%
with mlflow.start_run():

    mlflow.set_tag("developer", "cristian")

    mlflow.log_param("train-data-path", "./data/green_tripdata_2021-01.parquet")
    mlflow.log_param("valid-data-path", "./data/green_tripdata_2021-02.parquet")

    alpha = 0.01
    mlflow.log_param("alpha", alpha)
    lr = Lasso(alpha)
    lr.fit(X_train, y_train)

    y_pred = lr.predict(X_val)
    rmse = mean_squared_error(y_val, y_pred, squared=False)
    mlflow.log_metric("rmse", rmse)

    mlflow.log_artifact(local_path="models/lin_reg.bin", artifact_path="models_pickle")
# Out:
# /Users/weishanhe/opt/miniconda3/envs/mlops/lib/python3.9/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
import xgboost as xgb

# %%
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

# %%
train = xgb.DMatrix(X_train, label=y_train)
valid = xgb.DMatrix(X_val, label=y_val)

# %%
def objective(params):
    with mlflow.start_run():
        mlflow.set_tag("model", "xgboost")
        mlflow.log_params(params)
        booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=1000,
            evals=[(valid, 'validation')],
            early_stopping_rounds=50
        )
        y_pred = booster.predict(valid)
        rmse = mean_squared_error(y_val, y_pred, squared=False)
        mlflow.log_metric("rmse", rmse)

    return {'loss': rmse, 'status': STATUS_OK}

# %%
search_space = {
    'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
    'learning_rate': hp.loguniform('learning_rate', -3, 0), # exp(-3), exp(0) - [0.05, 1]
    'reg_alpha': hp.loguniform('reg_alpha', -5, -1),
    'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
    'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
    'objective': 'reg:linear',
    'seed': 42
}

best_result = fmin(
    fn=objective,
    space=search_space,
    algo=tpe.suggest,
    max_evals=50,
    trials=Trials()
)
# Out:
# [0]	validation-rmse:8.77362
#   0%|          | 0/50 [00:00<?, ?trial/s, best loss=?]
# /Users/weishanhe/opt/miniconda3/envs/mlops/lib/python3.9/site-packages/xgboost/core.py:160: UserWarning: [23:48:11] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [1]	validation-rmse:7.41847
# [2]	validation-rmse:6.92566
# [3]	validation-rmse:6.73735
# [4]	validation-rmse:6.65530
# [5]	validation-rmse:6.61400
# [6]	validation-rmse:6.59376
# [7]	validation-rmse:6.58409
# [8]	validation-rmse:6.57972
# [9]	validation-rmse:6.57148
# [10]	validation-rmse:6.56788
# [11]	validation-rmse:6.56165
# [12]	validation-rmse:6.55783
# [13]	validation-rmse:6.55430
# [14]	validation-rmse:6.55148
# [15]	validation-rmse:6.54394
# [16]	validation-rmse:6.54034
# [17]	validation-rmse:6.53686
# [18]	validation-rmse:6.53114
# [19]	validation-rmse:6.52735
# [20]	validation-rmse:6.52428
# [21]	validation-rmse:6.51920
# [22]	validation-rmse:6.51679
# [23]	validation-rmse:6.51537
# [24]	validation-rmse:6.51277
# [25]	validation-rmse:6.50964
# [26]	validation-rmse:6.50792
# [27]	validation-rmse:6.50446
# [28]	validation-rmse:6.50167
# [29]	validation-rmse:6.50042
# [30]	validation-rmse:6.49757
# [31]	validation-rmse:6.49508
# [32]	validation-rmse:6.49304
# [33]	validation-rmse:6.48996
# [34]	validation-rmse:6.48726
# [35]	validation-rmse:6.48648
# [36]	validation-rmse:6.48196
# [37]	validation-rmse:6.47796
# [38]	validation-rmse:6.47652
# [39]	validation-rmse:6.47381
# [40]	validation-rmse:6.47214
# [41]	validation-rmse:6.46904
# [42]	validation-rmse:6.46714
# [43]	validation-rmse:6.46548
# [44]	validation-rmse:6.46423
# [45]	validation-rmse:6.46308
# [46]	validation-rmse:6.46145
# [47]	validation-rmse:6.45950
# [48]	validation-rmse:6.45866
# [49]	validation-rmse:6.45696
# [50]	validation-rmse:6.45509
# [51]	validation-rmse:6.45347
# [52]	validation-rmse:6.45211
# [53]	validation-rmse:6.45034
# [54]	validation-rmse:6.44933
# [55]	validation-rmse:6.44778
# [56]	validation-rmse:6.44755
# [57]	validation-rmse:6.44705
# [58]	validation-rmse:6.44503
# [59]	validation-rmse:6.44298
# [60]	validation-rmse:6.44070
# [61]	validation-rmse:6.43963
# [62]	validation-rmse:6.43694
# [63]	validation-rmse:6.43631
# [64]	validation-rmse:6.43523
# [65]	validation-rmse:6.43458
# [66]	validation-rmse:6.43308
# [67]	validation-rmse:6.43077
# [68]	validation-rmse:6.43016
# [69]	validation-rmse:6.42775
# [70]	validation-rmse:6.42797
# [71]	validation-rmse:6.42710
# [72]	validation-rmse:6.42527
# [73]	validation-rmse:6.42493
# [74]	validation-rmse:6.42361
# [75]	validation-rmse:6.42288
# [76]	validation-rmse:6.42138
# [77]	validation-rmse:6.42053
# [78]	validation-rmse:6.41903
# [79]	validation-rmse:6.41829
# [80]	validation-rmse:6.41711
# [81]	validation-rmse:6.41691
# [82]	validation-rmse:6.41719
# [83]	validation-rmse:6.41646
# [84]	validation-rmse:6.41442
# [85]	validation-rmse:6.41340
# [86]	validation-rmse:6.41111
# [87]	validation-rmse:6.40986
# [88]	validation-rmse:6.40829
# [89]	validation-rmse:6.40768
# [90]	validation-rmse:6.40672
# [91]	validation-rmse:6.40737
# [92]	validation-rmse:6.40500
# [93]	validation-rmse:6.40413
# [94]	validation-rmse:6.40374
# [95]	validation-rmse:6.40281
# [96]	validation-rmse:6.40176
# [97]	validation-rmse:6.40089
# [98]	validation-rmse:6.40074
# [99]	validation-rmse:6.39949
# [100]	validation-rmse:6.39896
# [101]	validation-rmse:6.39809
# [102]	validation-rmse:6.39707
# [103]	validation-rmse:6.39613
# [104]	validation-rmse:6.39536
# [105]	validation-rmse:6.39440
# [106]	validation-rmse:6.39430
# [107]	validation-rmse:6.39352
# [108]	validation-rmse:6.39233
# [109]	validation-rmse:6.39195
# [110]	validation-rmse:6.39029
# [111]	validation-rmse:6.38910
# [112]	validation-rmse:6.38885
# [113]	validation-rmse:6.38893
# [114]	validation-rmse:6.38764
# [115]	validation-rmse:6.38666
# [116]	validation-rmse:6.38660
# [117]	validation-rmse:6.38581
# [118]	validation-rmse:6.38533
# [119]	validation-rmse:6.38490
# [120]	validation-rmse:6.38382
# [121]	validation-rmse:6.38262
# [122]	validation-rmse:6.38236
# [123]	validation-rmse:6.38147
# [124]	validation-rmse:6.38080
# [125]	validation-rmse:6.38045
# [126]	validation-rmse:6.37881
# [127]	validation-rmse:6.37803
# [128]	validation-rmse:6.37786
# [129]	validation-rmse:6.37727
# [130]	validation-rmse:6.37586
# [131]	validation-rmse:6.37529
# [132]	validation-rmse:6.37473
# [133]	validation-rmse:6.37403
# [134]	validation-rmse:6.37326
# [135]	validation-rmse:6.37265
# [136]	validation-rmse:6.37282
# [137]	validation-rmse:6.37126
# [138]	validation-rmse:6.37087
# [139]	validation-rmse:6.37079
# [140]	validation-rmse:6.37065
# [141]	validation-rmse:6.37058
# [142]	validation-rmse:6.36997
# [143]	validation-rmse:6.36911
# [144]	validation-rmse:6.36831
# [145]	validation-rmse:6.36836
# [146]	validation-rmse:6.36823
# [147]	validation-rmse:6.36688
# [148]	validation-rmse:6.36703
# [149]	validation-rmse:6.36653
# [150]	validation-rmse:6.36531
# [151]	validation-rmse:6.36485
# [152]	validation-rmse:6.36414
# [153]	validation-rmse:6.36183
# [154]	validation-rmse:6.36191
# [155]	validation-rmse:6.36128
# [156]	validation-rmse:6.36055
# [157]	validation-rmse:6.35919
# [158]	validation-rmse:6.35819
# [159]	validation-rmse:6.35795
# [160]	validation-rmse:6.35777
# [161]	validation-rmse:6.35728
# [162]	validation-rmse:6.35662
# [163]	validation-rmse:6.35570
# [164]	validation-rmse:6.35546
# [165]	validation-rmse:6.35497
# [166]	validation-rmse:6.35510
# [167]	validation-rmse:6.35543
# [168]	validation-rmse:6.35508
# [169]	validation-rmse:6.35518
# [170]	validation-rmse:6.35467
# [171]	validation-rmse:6.35436
# [172]	validation-rmse:6.35366
# [173]	validation-rmse:6.35343
# [174]	validation-rmse:6.35357
# [175]	validation-rmse:6.35381
# [176]	validation-rmse:6.35357
# [177]	validation-rmse:6.35311
# [178]	validation-rmse:6.35179
# [179]	validation-rmse:6.35177
# [180]	validation-rmse:6.35199
# [181]	validation-rmse:6.35190
# [182]	validation-rmse:6.34982
# [183]	validation-rmse:6.34947
# [184]	validation-rmse:6.34952
# [185]	validation-rmse:6.34865
# [186]	validation-rmse:6.34859
# [187]	validation-rmse:6.34821
# [188]	validation-rmse:6.34738
# [189]	validation-rmse:6.34719
# [190]	validation-rmse:6.34620
# [191]	validation-rmse:6.34564
# [192]	validation-rmse:6.34557
# [193]	validation-rmse:6.34604
# [194]	validation-rmse:6.34617
# [195]	validation-rmse:6.34647
# [196]	validation-rmse:6.34632
# [197]	validation-rmse:6.34588
# [198]	validation-rmse:6.34584
# [199]	validation-rmse:6.34564
# [200]	validation-rmse:6.34522
# [201]	validation-rmse:6.34522
# [202]	validation-rmse:6.34542
# [203]	validation-rmse:6.34544
# [204]	validation-rmse:6.34517
# [205]	validation-rmse:6.34519
# [206]	validation-rmse:6.34517
# [207]	validation-rmse:6.34449
# [208]	validation-rmse:6.34459
# [209]	validation-rmse:6.34450
# [210]	validation-rmse:6.34361
# [211]	validation-rmse:6.34363
# [212]	validation-rmse:6.34375
# [213]	validation-rmse:6.34375
# [214]	validation-rmse:6.34366
# [215]	validation-rmse:6.34370
# [216]	validation-rmse:6.34366
# [217]	validation-rmse:6.34319
# [218]	validation-rmse:6.34395
# [219]	validation-rmse:6.34416
# [220]	validation-rmse:6.34059
# [221]	validation-rmse:6.33999
# [222]	validation-rmse:6.33955
# [223]	validation-rmse:6.33944
# [224]	validation-rmse:6.33695
# [225]	validation-rmse:6.33690
# [226]	validation-rmse:6.33669
# [227]	validation-rmse:6.33699
# [228]	validation-rmse:6.33680
# [229]	validation-rmse:6.33689
# [230]	validation-rmse:6.33720
# [231]	validation-rmse:6.33685
# [232]	validation-rmse:6.33678
# [233]	validation-rmse:6.33675
# [234]	validation-rmse:6.33629
# [235]	validation-rmse:6.33607
# [236]	validation-rmse:6.33580
# [237]	validation-rmse:6.33546
# [238]	validation-rmse:6.33531
# [239]	validation-rmse:6.33515
# [240]	validation-rmse:6.33519
# [241]	validation-rmse:6.33536
# [242]	validation-rmse:6.33512
# [243]	validation-rmse:6.33474
# [244]	validation-rmse:6.33478
# [245]	validation-rmse:6.33469
# [246]	validation-rmse:6.33496
# [247]	validation-rmse:6.33489
# [248]	validation-rmse:6.33427
# [249]	validation-rmse:6.33432
# [250]	validation-rmse:6.33402
# [251]	validation-rmse:6.33413
# [252]	validation-rmse:6.33405
# [253]	validation-rmse:6.33392
# [254]	validation-rmse:6.33396
# [255]	validation-rmse:6.33263
# [256]	validation-rmse:6.33265
# [257]	validation-rmse:6.33280
# [258]	validation-rmse:6.33358
# [259]	validation-rmse:6.33352
# [260]	validation-rmse:6.33357
# [261]	validation-rmse:6.33320
# [262]	validation-rmse:6.33307
# [263]	validation-rmse:6.33368
# [264]	validation-rmse:6.33316
# [265]	validation-rmse:6.33297
# [266]	validation-rmse:6.33334
# [267]	validation-rmse:6.33340
# [268]	validation-rmse:6.33214
# [269]	validation-rmse:6.33213
# [270]	validation-rmse:6.33252
# [271]	validation-rmse:6.33239
# [272]	validation-rmse:6.33204
# [273]	validation-rmse:6.33199
# [274]	validation-rmse:6.33072
# [275]	validation-rmse:6.33152
# [276]	validation-rmse:6.33127
# [277]	validation-rmse:6.33080
# [278]	validation-rmse:6.33003
# [279]	validation-rmse:6.32994
# [280]	validation-rmse:6.32953
# [281]	validation-rmse:6.32978
# [282]	validation-rmse:6.32926
# [283]	validation-rmse:6.32982
# [284]	validation-rmse:6.32991
# [285]	validation-rmse:6.33116
# [286]	validation-rmse:6.33024
# [287]	validation-rmse:6.33004
# [288]	validation-rmse:6.33064
# [289]	validation-rmse:6.33014
# [290]	validation-rmse:6.32996
# [291]	validation-rmse:6.32618
# [292]	validation-rmse:6.32547
# [293]	validation-rmse:6.32487
# [294]	validation-rmse:6.32330
# [295]	validation-rmse:6.32327
# [296]	validation-rmse:6.32301
# [297]	validation-rmse:6.32295
# [298]	validation-rmse:6.32269
# [299]	validation-rmse:6.32295
# [300]	validation-rmse:6.32303
# [301]	validation-rmse:6.32264
# [302]	validation-rmse:6.32272
# [303]	validation-rmse:6.32242
# [304]	validation-rmse:6.32270
# [305]	validation-rmse:6.32254
# [306]	validation-rmse:6.32200
# [307]	validation-rmse:6.32214
# [308]	validation-rmse:6.32218
# [309]	validation-rmse:6.32227
# [310]	validation-rmse:6.32180
# [311]	validation-rmse:6.32113
# [312]	validation-rmse:6.32125
# [313]	validation-rmse:6.32147
# [314]	validation-rmse:6.32173
# [315]	validation-rmse:6.32159
# [316]	validation-rmse:6.32097
# [317]	validation-rmse:6.32054
# [318]	validation-rmse:6.32035
# [319]	validation-rmse:6.32029
# [320]	validation-rmse:6.32021
# [321]	validation-rmse:6.31965
# [322]	validation-rmse:6.31952
# [323]	validation-rmse:6.31935
# [324]	validation-rmse:6.31948
# [325]	validation-rmse:6.32031
# [326]	validation-rmse:6.32063
# [327]	validation-rmse:6.32025
# [328]	validation-rmse:6.32024
# [329]	validation-rmse:6.32057
# [330]	validation-rmse:6.32020
# [331]	validation-rmse:6.32046
# [332]	validation-rmse:6.32055
# [333]	validation-rmse:6.32075
# [334]	validation-rmse:6.32119
# [335]	validation-rmse:6.32120
# [336]	validation-rmse:6.32112
# [337]	validation-rmse:6.32114
# [338]	validation-rmse:6.32096
# [339]	validation-rmse:6.32088
# [340]	validation-rmse:6.32074
# [341]	validation-rmse:6.32101
# [342]	validation-rmse:6.32110
# [343]	validation-rmse:6.32051
# [344]	validation-rmse:6.32088
# [345]	validation-rmse:6.32035
# [346]	validation-rmse:6.32047
# [347]	validation-rmse:6.32023
# [348]	validation-rmse:6.32024
# [349]	validation-rmse:6.32034
# [350]	validation-rmse:6.31996
# [351]	validation-rmse:6.32003
# [352]	validation-rmse:6.32012
# [353]	validation-rmse:6.32006
# [354]	validation-rmse:6.31990
# [355]	validation-rmse:6.31977
# [356]	validation-rmse:6.31963
# [357]	validation-rmse:6.31903
# [358]	validation-rmse:6.31895
# [359]	validation-rmse:6.31900
# [360]	validation-rmse:6.31879
# [361]	validation-rmse:6.31863
# [362]	validation-rmse:6.31827
# [363]	validation-rmse:6.31811
# [364]	validation-rmse:6.31799
# [365]	validation-rmse:6.31786
# [366]	validation-rmse:6.31777
# [367]	validation-rmse:6.31858
# [368]	validation-rmse:6.31857
# [369]	validation-rmse:6.31889
# [370]	validation-rmse:6.31943
# [371]	validation-rmse:6.31921
# [372]	validation-rmse:6.31952
# [373]	validation-rmse:6.31984
# [374]	validation-rmse:6.31952
# [375]	validation-rmse:6.31970
# [376]	validation-rmse:6.31971
# [377]	validation-rmse:6.31972
# [378]	validation-rmse:6.31962
# [379]	validation-rmse:6.31946
# [380]	validation-rmse:6.31943
# [381]	validation-rmse:6.31949
# [382]	validation-rmse:6.31964
# [383]	validation-rmse:6.31952
# [384]	validation-rmse:6.31936
# [385]	validation-rmse:6.32012
# [386]	validation-rmse:6.32025
# [387]	validation-rmse:6.32047
# [388]	validation-rmse:6.32033
# [389]	validation-rmse:6.32043
# [390]	validation-rmse:6.31996
# [391]	validation-rmse:6.31989
# [392]	validation-rmse:6.31999
# [393]	validation-rmse:6.31864
# [394]	validation-rmse:6.31785
# [395]	validation-rmse:6.31781
# [396]	validation-rmse:6.31789
# [397]	validation-rmse:6.31792
# [398]	validation-rmse:6.31768
# [399]	validation-rmse:6.31847
# [400]	validation-rmse:6.31824
# [401]	validation-rmse:6.31884
# [402]	validation-rmse:6.31891
# [403]	validation-rmse:6.31877
# [404]	validation-rmse:6.31868
# [405]	validation-rmse:6.31902
# [406]	validation-rmse:6.31867
# [407]	validation-rmse:6.31848
# [408]	validation-rmse:6.31819
# [409]	validation-rmse:6.31793
# [410]	validation-rmse:6.31788
# [411]	validation-rmse:6.31825
# [412]	validation-rmse:6.31825
# [413]	validation-rmse:6.31802
# [414]	validation-rmse:6.31632
# [415]	validation-rmse:6.31461
# [416]	validation-rmse:6.31497
# [417]	validation-rmse:6.31539
# [418]	validation-rmse:6.31555
# [419]	validation-rmse:6.31554
# [420]	validation-rmse:6.31552
# [421]	validation-rmse:6.31553
# [422]	validation-rmse:6.31537
# [423]	validation-rmse:6.31502
# [424]	validation-rmse:6.31506
# [425]	validation-rmse:6.31502
# [426]	validation-rmse:6.31513
# [427]	validation-rmse:6.31604
# [428]	validation-rmse:6.31577
# [429]	validation-rmse:6.31576
# [430]	validation-rmse:6.31627
# [431]	validation-rmse:6.31634
# [432]	validation-rmse:6.31708
# [433]	validation-rmse:6.31704
# [434]	validation-rmse:6.31592
# [435]	validation-rmse:6.31507
# [436]	validation-rmse:6.31507
# [437]	validation-rmse:6.31503
# [438]	validation-rmse:6.31513
# [439]	validation-rmse:6.31459
# [440]	validation-rmse:6.31413
# [441]	validation-rmse:6.31391
# [442]	validation-rmse:6.31368
# [443]	validation-rmse:6.31414
# [444]	validation-rmse:6.31354
# [445]	validation-rmse:6.31358
# [446]	validation-rmse:6.31389
# [447]	validation-rmse:6.31390
# [448]	validation-rmse:6.31382
# [449]	validation-rmse:6.31421
# [450]	validation-rmse:6.31473
# [451]	validation-rmse:6.31476
# [452]	validation-rmse:6.31432
# [453]	validation-rmse:6.31434
# [454]	validation-rmse:6.31451
# [455]	validation-rmse:6.31472
# [456]	validation-rmse:6.31502
# [457]	validation-rmse:6.31592
# [458]	validation-rmse:6.31579
# [459]	validation-rmse:6.31575
# [460]	validation-rmse:6.31582
# [461]	validation-rmse:6.31586
# [462]	validation-rmse:6.31604
# [463]	validation-rmse:6.31600
# [464]	validation-rmse:6.31572
# [465]	validation-rmse:6.31548
# [466]	validation-rmse:6.31557
# [467]	validation-rmse:6.31696
# [468]	validation-rmse:6.31676
# [469]	validation-rmse:6.31661
# [470]	validation-rmse:6.31645
# [471]	validation-rmse:6.31647
# [472]	validation-rmse:6.31646
# [473]	validation-rmse:6.31670
# [474]	validation-rmse:6.31668
# [475]	validation-rmse:6.31718
# [476]	validation-rmse:6.31693
# [477]	validation-rmse:6.31679
# [478]	validation-rmse:6.31684
# [479]	validation-rmse:6.31685
# [480]	validation-rmse:6.31728
# [481]	validation-rmse:6.31716
# [482]	validation-rmse:6.31738
# [483]	validation-rmse:6.31651
# [484]	validation-rmse:6.31727
# [485]	validation-rmse:6.31759
# [486]	validation-rmse:6.31765
# [487]	validation-rmse:6.31776
# [488]	validation-rmse:6.31706
# [489]	validation-rmse:6.31710
# [490]	validation-rmse:6.31710
# [491]	validation-rmse:6.31709
# [492]	validation-rmse:6.31733
# [493]	validation-rmse:6.31758
# [494]	validation-rmse:6.31756
#   2%|▏         | 1/50 [00:23<19:31, 23.91s/trial, best loss: 6.3175575358156815]
# /Users/weishanhe/opt/miniconda3/envs/mlops/lib/python3.9/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
#
# /Users/weishanhe/opt/miniconda3/envs/mlops/lib/python3.9/site-packages/xgboost/core.py:160: UserWarning: [23:48:35] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [0]	validation-rmse:11.62635
# [1]	validation-rmse:11.09542
# [2]	validation-rmse:10.61662
# [3]	validation-rmse:10.18503
# [4]	validation-rmse:9.79628
# [5]	validation-rmse:9.44875
# [6]	validation-rmse:9.13577
# [7]	validation-rmse:8.85573
# [8]	validation-rmse:8.60896
# [9]	validation-rmse:8.38698
# [10]	validation-rmse:8.19095
# [11]	validation-rmse:8.01326
# [12]	validation-rmse:7.85999
# [13]	validation-rmse:7.72061
# [14]	validation-rmse:7.59927
# [15]	validation-rmse:7.48895
# [16]	validation-rmse:7.39493
# [17]	validation-rmse:7.30976
# [18]	validation-rmse:7.23513
# [19]	validation-rmse:7.16723
# [20]	validation-rmse:7.10805
# [21]	validation-rmse:7.05567
# [22]	validation-rmse:7.00967
# [23]	validation-rmse:6.96754
# [24]	validation-rmse:6.93088
# [25]	validation-rmse:6.89839
# [26]	validation-rmse:6.86808
# [27]	validation-rmse:6.84180
# [28]	validation-rmse:6.81650
# [29]	validation-rmse:6.79480
# [30]	validation-rmse:6.77455
# [31]	validation-rmse:6.75702
# [32]	validation-rmse:6.74203
# [33]	validation-rmse:6.72741
# [34]	validation-rmse:6.71543
# [35]	validation-rmse:6.70411
# [36]	validation-rmse:6.69226
# [37]	validation-rmse:6.68393
# [38]	validation-rmse:6.67426
# [39]	validation-rmse:6.66669
# [40]	validation-rmse:6.66005
# [41]	validation-rmse:6.65355
# [42]	validation-rmse:6.64803
# [43]	validation-rmse:6.64292
# [44]	validation-rmse:6.63787
# [45]	validation-rmse:6.63327
# [46]	validation-rmse:6.62882
# [47]	validation-rmse:6.62538
# [48]	validation-rmse:6.62170
# [49]	validation-rmse:6.61857
# [50]	validation-rmse:6.61530
# [51]	validation-rmse:6.61262
# [52]	validation-rmse:6.60997
# [53]	validation-rmse:6.60770
# [54]	validation-rmse:6.60555
# [55]	validation-rmse:6.60392
# [56]	validation-rmse:6.60200
# [57]	validation-rmse:6.60040
# [58]	validation-rmse:6.59823
# [59]	validation-rmse:6.59682
# [60]	validation-rmse:6.59541
# [61]	validation-rmse:6.59390
# [62]	validation-rmse:6.59232
# [63]	validation-rmse:6.59133
# [64]	validation-rmse:6.59006
# [65]	validation-rmse:6.58885
# [66]	validation-rmse:6.58758
# [67]	validation-rmse:6.58672
# [68]	validation-rmse:6.58582
# [69]	validation-rmse:6.58515
# [70]	validation-rmse:6.58393
# [71]	validation-rmse:6.58349
# [72]	validation-rmse:6.58287
# [73]	validation-rmse:6.58189
# [74]	validation-rmse:6.58137
# [75]	validation-rmse:6.58076
# [76]	validation-rmse:6.57993
# [77]	validation-rmse:6.57867
# [78]	validation-rmse:6.57762
# [79]	validation-rmse:6.57703
# [80]	validation-rmse:6.57624
# [81]	validation-rmse:6.57529
# [82]	validation-rmse:6.57466
# [83]	validation-rmse:6.57415
# [84]	validation-rmse:6.57371
# [85]	validation-rmse:6.57326
# [86]	validation-rmse:6.57296
# [87]	validation-rmse:6.57241
# [88]	validation-rmse:6.57167
# [89]	validation-rmse:6.57110
# [90]	validation-rmse:6.57053
# [91]	validation-rmse:6.56975
# [92]	validation-rmse:6.56956
# [93]	validation-rmse:6.56882
# [94]	validation-rmse:6.56828
# [95]	validation-rmse:6.56740
# [96]	validation-rmse:6.56619
# [97]	validation-rmse:6.56544
# [98]	validation-rmse:6.56486
# [99]	validation-rmse:6.56420
# [100]	validation-rmse:6.56342
# [101]	validation-rmse:6.56299
# [102]	validation-rmse:6.56252
# [103]	validation-rmse:6.56214
# [104]	validation-rmse:6.56183
# [105]	validation-rmse:6.56149
# [106]	validation-rmse:6.56102
# [107]	validation-rmse:6.56067
# [108]	validation-rmse:6.55993
# [109]	validation-rmse:6.55938
# [110]	validation-rmse:6.55922
# [111]	validation-rmse:6.55887
# [112]	validation-rmse:6.55814
# [113]	validation-rmse:6.55770
# [114]	validation-rmse:6.55731
# [115]	validation-rmse:6.55691
# [116]	validation-rmse:6.55653
# [117]	validation-rmse:6.55614
# [118]	validation-rmse:6.55611
# [119]	validation-rmse:6.55570
# [120]	validation-rmse:6.55493
# [121]	validation-rmse:6.55439
# [122]	validation-rmse:6.55401
# [123]	validation-rmse:6.55335
# [124]	validation-rmse:6.55260
# [125]	validation-rmse:6.55203
# [126]	validation-rmse:6.55142
# [127]	validation-rmse:6.55104
# [128]	validation-rmse:6.55049
# [129]	validation-rmse:6.54997
# [130]	validation-rmse:6.54940
# [131]	validation-rmse:6.54905
# [132]	validation-rmse:6.54878
# [133]	validation-rmse:6.54835
# [134]	validation-rmse:6.54818
# [135]	validation-rmse:6.54759
# [136]	validation-rmse:6.54719
# [137]	validation-rmse:6.54684
# [138]	validation-rmse:6.54660
# [139]	validation-rmse:6.54615
# [140]	validation-rmse:6.54577
# [141]	validation-rmse:6.54535
# [142]	validation-rmse:6.54512
# [143]	validation-rmse:6.54474
# [144]	validation-rmse:6.54449
# [145]	validation-rmse:6.54431
# [146]	validation-rmse:6.54408
# [147]	validation-rmse:6.54379
# [148]	validation-rmse:6.54360
# [149]	validation-rmse:6.54334
# [150]	validation-rmse:6.54263
# [151]	validation-rmse:6.54238
# [152]	validation-rmse:6.54197
# [153]	validation-rmse:6.54137
# [154]	validation-rmse:6.54100
# [155]	validation-rmse:6.54058
# [156]	validation-rmse:6.54031
# [157]	validation-rmse:6.54000
# [158]	validation-rmse:6.53969
# [159]	validation-rmse:6.53944
# [160]	validation-rmse:6.53901
# [161]	validation-rmse:6.53852
# [162]	validation-rmse:6.53804
# [163]	validation-rmse:6.53780
# [164]	validation-rmse:6.53708
# [165]	validation-rmse:6.53632
# [166]	validation-rmse:6.53585
# [167]	validation-rmse:6.53544
# [168]	validation-rmse:6.53518
# [169]	validation-rmse:6.53497
# [170]	validation-rmse:6.53469
# [171]	validation-rmse:6.53428
# [172]	validation-rmse:6.53396
# [173]	validation-rmse:6.53375
# [174]	validation-rmse:6.53343
# [175]	validation-rmse:6.53316
# [176]	validation-rmse:6.53273
# [177]	validation-rmse:6.53248
# [178]	validation-rmse:6.53206
# [179]	validation-rmse:6.53156
# [180]	validation-rmse:6.53139
# [181]	validation-rmse:6.53099
# [182]	validation-rmse:6.53080
# [183]	validation-rmse:6.53042
# [184]	validation-rmse:6.52997
# [185]	validation-rmse:6.52951
# [186]	validation-rmse:6.52945
# [187]	validation-rmse:6.52908
# [188]	validation-rmse:6.52895
# [189]	validation-rmse:6.52869
# [190]	validation-rmse:6.52850
# [191]	validation-rmse:6.52834
# [192]	validation-rmse:6.52821
# [193]	validation-rmse:6.52808
# [194]	validation-rmse:6.52796
# [195]	validation-rmse:6.52768
# [196]	validation-rmse:6.52725
# [197]	validation-rmse:6.52714
# [198]	validation-rmse:6.52692
# [199]	validation-rmse:6.52660
# [200]	validation-rmse:6.52629
# [201]	validation-rmse:6.52607
# [202]	validation-rmse:6.52571
# [203]	validation-rmse:6.52546
# [204]	validation-rmse:6.52517
# [205]	validation-rmse:6.52473
# [206]	validation-rmse:6.52460
# [207]	validation-rmse:6.52423
# [208]	validation-rmse:6.52370
# [209]	validation-rmse:6.52343
# [210]	validation-rmse:6.52313
# [211]	validation-rmse:6.52270
# [212]	validation-rmse:6.52243
# [213]	validation-rmse:6.52219
# [214]	validation-rmse:6.52180
# [215]	validation-rmse:6.52158
# [216]	validation-rmse:6.52130
# [217]	validation-rmse:6.52116
# [218]	validation-rmse:6.52100
# [219]	validation-rmse:6.52067
# [220]	validation-rmse:6.52043
# [221]	validation-rmse:6.52010
# [222]	validation-rmse:6.51985
# [223]	validation-rmse:6.51963
# [224]	validation-rmse:6.51917
# [225]	validation-rmse:6.51890
# [226]	validation-rmse:6.51871
# [227]	validation-rmse:6.51840
# [228]	validation-rmse:6.51821
# [229]	validation-rmse:6.51810
# [230]	validation-rmse:6.51782
# [231]	validation-rmse:6.51736
# [232]	validation-rmse:6.51694
# [233]	validation-rmse:6.51666
# [234]	validation-rmse:6.51657
# [235]	validation-rmse:6.51631
# [236]	validation-rmse:6.51594
# [237]	validation-rmse:6.51582
# [238]	validation-rmse:6.51552
# [239]	validation-rmse:6.51537
# [240]	validation-rmse:6.51485
# [241]	validation-rmse:6.51453
# [242]	validation-rmse:6.51432
# [243]	validation-rmse:6.51400
# ...
# [808]	validation-rmse:6.38062
# [809]	validation-rmse:6.38063
# [810]	validation-rmse:6.38076
# [811]	validation-rmse:6.38067
# [812]	validation-rmse:6.38090
# [813]	validation-rmse:6.38088
# [814]	validation-rmse:6.38092
# [815]	validation-rmse:6.38041
# [816]	validation-rmse:6.38035
# [817]	validation-rmse:6.38035
# [818]	validation-rmse:6.38051
# [819]	validation-rmse:6.38051
# [820]	validation-rmse:6.38042
# [821]	validation-rmse:6.38026
# [822]	validation-rmse:6.38017
# [823]	validation-rmse:6.38038
# [824]	validation-rmse:6.38035
# [825]	validation-rmse:6.38017
# [826]	validation-rmse:6.38015
# [827]	validation-rmse:6.37995
# [828]	validation-rmse:6.38017
# [829]	validation-rmse:6.38018
# [830]	validation-rmse:6.38005
# [831]	validation-rmse:6.37993
# [832]	validation-rmse:6.37992
# [833]	validation-rmse:6.38002
# [834]	validation-rmse:6.37974
# [835]	validation-rmse:6.37969
# [836]	validation-rmse:6.37966
# [837]	validation-rmse:6.37971
# [838]	validation-rmse:6.37963
# [839]	validation-rmse:6.37965
# [840]	validation-rmse:6.37967
# [841]	validation-rmse:6.37967
# [842]	validation-rmse:6.37949
# [843]	validation-rmse:6.37940
# [844]	validation-rmse:6.37937
# [845]	validation-rmse:6.37922
# [846]	validation-rmse:6.37926
# [847]	validation-rmse:6.37913
# [848]	validation-rmse:6.37938
# [849]	validation-rmse:6.37943
# [850]	validation-rmse:6.37927
# [851]	validation-rmse:6.37931
# [852]	validation-rmse:6.37956
# [853]	validation-rmse:6.37956
# [854]	validation-rmse:6.37954
# [855]	validation-rmse:6.37936
# [856]	validation-rmse:6.37932
# [857]	validation-rmse:6.37920
# [858]	validation-rmse:6.37929
# [859]	validation-rmse:6.37930
# [860]	validation-rmse:6.37902
# [861]	validation-rmse:6.37945
# [862]	validation-rmse:6.37951
# [863]	validation-rmse:6.37956
# [864]	validation-rmse:6.37952
# [865]	validation-rmse:6.37957
# [866]	validation-rmse:6.37944
# [867]	validation-rmse:6.37948
# [868]	validation-rmse:6.37933
# [869]	validation-rmse:6.37910
# [870]	validation-rmse:6.37918
# [871]	validation-rmse:6.37925
# [872]	validation-rmse:6.37887
# [873]	validation-rmse:6.37873
# [874]	validation-rmse:6.37863
# [875]	validation-rmse:6.37854
# [876]	validation-rmse:6.37857
# [877]	validation-rmse:6.37857
# [878]	validation-rmse:6.37841
# [879]	validation-rmse:6.37838
# [880]	validation-rmse:6.37834
# [881]	validation-rmse:6.37828
# [882]	validation-rmse:6.37823
# [883]	validation-rmse:6.37808
# [884]	validation-rmse:6.37815
# [885]	validation-rmse:6.37804
# [886]	validation-rmse:6.37798
# [887]	validation-rmse:6.37799
# [888]	validation-rmse:6.37788
# [889]	validation-rmse:6.37792
# [890]	validation-rmse:6.37782
# [891]	validation-rmse:6.37761
# [892]	validation-rmse:6.37756
# [893]	validation-rmse:6.37754
# [894]	validation-rmse:6.37775
# [895]	validation-rmse:6.37764
# [896]	validation-rmse:6.37767
# [897]	validation-rmse:6.37768
# [898]	validation-rmse:6.37754
# [899]	validation-rmse:6.37748
# [900]	validation-rmse:6.37742
# [901]	validation-rmse:6.37761
# [902]	validation-rmse:6.37752
# [903]	validation-rmse:6.37734
# [904]	validation-rmse:6.37740
# [905]	validation-rmse:6.37743
# [906]	validation-rmse:6.37745
# [907]	validation-rmse:6.37743
# [908]	validation-rmse:6.37751
# [909]	validation-rmse:6.37737
# [910]	validation-rmse:6.37756
# [911]	validation-rmse:6.37753
# [912]	validation-rmse:6.37754
# [913]	validation-rmse:6.37742
# [914]	validation-rmse:6.37748
# [915]	validation-rmse:6.37750
# [916]	validation-rmse:6.37725
# [917]	validation-rmse:6.37718
# [918]	validation-rmse:6.37737
# [919]	validation-rmse:6.37723
# [920]	validation-rmse:6.37721
# [921]	validation-rmse:6.37716
# [922]	validation-rmse:6.37710
# [923]	validation-rmse:6.37704
# [924]	validation-rmse:6.37701
# [925]	validation-rmse:6.37698
# [926]	validation-rmse:6.37677
# [927]	validation-rmse:6.37675
# [928]	validation-rmse:6.37662
# [929]	validation-rmse:6.37673
# [930]	validation-rmse:6.37662
# [931]	validation-rmse:6.37664
# [932]	validation-rmse:6.37631
# [933]	validation-rmse:6.37628
# [934]	validation-rmse:6.37617
# [935]	validation-rmse:6.37595
# [936]	validation-rmse:6.37592
# [937]	validation-rmse:6.37602
# [938]	validation-rmse:6.37616
# [939]	validation-rmse:6.37603
# [940]	validation-rmse:6.37595
# [941]	validation-rmse:6.37591
# [942]	validation-rmse:6.37580
# [943]	validation-rmse:6.37592
# [944]	validation-rmse:6.37588
# [945]	validation-rmse:6.37574
# [946]	validation-rmse:6.37586
# [947]	validation-rmse:6.37582
# [948]	validation-rmse:6.37580
# [949]	validation-rmse:6.37563
# [950]	validation-rmse:6.37561
# [951]	validation-rmse:6.37547
# [952]	validation-rmse:6.37549
# [953]	validation-rmse:6.37544
# [954]	validation-rmse:6.37549
# [955]	validation-rmse:6.37562
# [956]	validation-rmse:6.37553
# [957]	validation-rmse:6.37547
# [958]	validation-rmse:6.37529
# [959]	validation-rmse:6.37521
# [960]	validation-rmse:6.37512
# [961]	validation-rmse:6.37509
# [962]	validation-rmse:6.37490
# [963]	validation-rmse:6.37490
# [964]	validation-rmse:6.37469
# [965]	validation-rmse:6.37470
# [966]	validation-rmse:6.37456
# [967]	validation-rmse:6.37436
# [968]	validation-rmse:6.37425
# [969]	validation-rmse:6.37432
# [970]	validation-rmse:6.37420
# [971]	validation-rmse:6.37398
# [972]	validation-rmse:6.37376
# [973]	validation-rmse:6.37395
# [974]	validation-rmse:6.37392
# [975]	validation-rmse:6.37387
# [976]	validation-rmse:6.37390
# [977]	validation-rmse:6.37383
# [978]	validation-rmse:6.37407
# [979]	validation-rmse:6.37466
# [980]	validation-rmse:6.37466
# [981]	validation-rmse:6.37437
# [982]	validation-rmse:6.37430
# [983]	validation-rmse:6.37437
# [984]	validation-rmse:6.37423
# [985]	validation-rmse:6.37423
# [986]	validation-rmse:6.37403
# [987]	validation-rmse:6.37407
# [988]	validation-rmse:6.37415
# [989]	validation-rmse:6.37430
# [990]	validation-rmse:6.37415
# [991]	validation-rmse:6.37411
# [992]	validation-rmse:6.37405
# [993]	validation-rmse:6.37389
# [994]	validation-rmse:6.37386
# [995]	validation-rmse:6.37363
# [996]	validation-rmse:6.37374
# [997]	validation-rmse:6.37367
# [998]	validation-rmse:6.37396
# [999]	validation-rmse:6.37399
# 100%|██████████| 50/50 [32:43<00:00, 39.28s/trial, best loss: 6.309495619325866]
# /Users/weishanhe/opt/miniconda3/envs/mlops/lib/python3.9/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
mlflow.xgboost.autolog(disable=True)

# %%
with mlflow.start_run():
    
    train = xgb.DMatrix(X_train, label=y_train)
    valid = xgb.DMatrix(X_val, label=y_val)

    best_params = {
        'learning_rate': 0.09585355369315604,
        'max_depth': 30,
        'min_child_weight': 1.060597050922164,
        'objective': 'reg:linear',
        'reg_alpha': 0.018060244040060163,
        'reg_lambda': 0.011658731377413597,
        'seed': 42
    }

    mlflow.log_params(best_params)

    booster = xgb.train(
        params=best_params,
        dtrain=train,
        num_boost_round=1000,
        evals=[(valid, 'validation')],
        early_stopping_rounds=50
    )

    y_pred = booster.predict(valid)
    rmse = mean_squared_error(y_val, y_pred, squared=False)
    mlflow.log_metric("rmse", rmse)

    with open("models/preprocessor.b", "wb") as f_out:
        pickle.dump(dv, f_out)
    mlflow.log_artifact("models/preprocessor.b", artifact_path="preprocessor")

    mlflow.xgboost.log_model(booster, artifact_path="models_mlflow")
# Out:
# /Users/weishanhe/opt/miniconda3/envs/mlops/lib/python3.9/site-packages/xgboost/core.py:160: UserWarning: [22:04:01] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [0]	validation-rmse:11.44482
# [1]	validation-rmse:10.77202
# [2]	validation-rmse:10.18363
# [3]	validation-rmse:9.67396
# [4]	validation-rmse:9.23166
# [5]	validation-rmse:8.84808
# [6]	validation-rmse:8.51883
# [7]	validation-rmse:8.23597
# [8]	validation-rmse:7.99320
# [9]	validation-rmse:7.78709
# [10]	validation-rmse:7.61022
# [11]	validation-rmse:7.45952
# [12]	validation-rmse:7.33049
# [13]	validation-rmse:7.22098
# [14]	validation-rmse:7.12713
# [15]	validation-rmse:7.04752
# [16]	validation-rmse:6.98005
# [17]	validation-rmse:6.92232
# [18]	validation-rmse:6.87112
# [19]	validation-rmse:6.82740
# [20]	validation-rmse:6.78995
# [21]	validation-rmse:6.75792
# [22]	validation-rmse:6.72994
# [23]	validation-rmse:6.70547
# [24]	validation-rmse:6.68390
# [25]	validation-rmse:6.66421
# [26]	validation-rmse:6.64806
# [27]	validation-rmse:6.63280
# [28]	validation-rmse:6.61924
# [29]	validation-rmse:6.60773
# [30]	validation-rmse:6.59777
# [31]	validation-rmse:6.58875
# [32]	validation-rmse:6.58107
# [33]	validation-rmse:6.57217
# [34]	validation-rmse:6.56557
# [35]	validation-rmse:6.56003
# [36]	validation-rmse:6.55392
# [37]	validation-rmse:6.54924
# [38]	validation-rmse:6.54536
# [39]	validation-rmse:6.54187
# [40]	validation-rmse:6.53873
# [41]	validation-rmse:6.53518
# [42]	validation-rmse:6.53287
# [43]	validation-rmse:6.53048
# [44]	validation-rmse:6.52858
# [45]	validation-rmse:6.52703
# [46]	validation-rmse:6.52566
# [47]	validation-rmse:6.52419
# [48]	validation-rmse:6.52323
# [49]	validation-rmse:6.52265
# [50]	validation-rmse:6.52202
# [51]	validation-rmse:6.52036
# [52]	validation-rmse:6.52003
# [53]	validation-rmse:6.51962
# [54]	validation-rmse:6.51829
# [55]	validation-rmse:6.51712
# [56]	validation-rmse:6.51598
# [57]	validation-rmse:6.51517
# [58]	validation-rmse:6.51442
# [59]	validation-rmse:6.51357
# [60]	validation-rmse:6.51194
# [61]	validation-rmse:6.51127
# [62]	validation-rmse:6.51044
# [63]	validation-rmse:6.50930
# [64]	validation-rmse:6.50840
# [65]	validation-rmse:6.50731
# [66]	validation-rmse:6.50635
# [67]	validation-rmse:6.50566
# [68]	validation-rmse:6.50458
# [69]	validation-rmse:6.50339
# [70]	validation-rmse:6.50239
# [71]	validation-rmse:6.50137
# [72]	validation-rmse:6.50014
# [73]	validation-rmse:6.49940
# [74]	validation-rmse:6.49835
# [75]	validation-rmse:6.49782
# [76]	validation-rmse:6.49697
# [77]	validation-rmse:6.49628
# [78]	validation-rmse:6.49561
# [79]	validation-rmse:6.49495
# [80]	validation-rmse:6.49429
# [81]	validation-rmse:6.49371
# [82]	validation-rmse:6.49317
# [83]	validation-rmse:6.49248
# [84]	validation-rmse:6.49170
# [85]	validation-rmse:6.49080
# [86]	validation-rmse:6.49020
# [87]	validation-rmse:6.48927
# [88]	validation-rmse:6.48842
# [89]	validation-rmse:6.48717
# [90]	validation-rmse:6.48666
# [91]	validation-rmse:6.48608
# [92]	validation-rmse:6.48531
# [93]	validation-rmse:6.48457
# [94]	validation-rmse:6.48376
# [95]	validation-rmse:6.48304
# [96]	validation-rmse:6.48246
# [97]	validation-rmse:6.48113
# [98]	validation-rmse:6.48052
# [99]	validation-rmse:6.47984
# [100]	validation-rmse:6.47922
# [101]	validation-rmse:6.47886
# [102]	validation-rmse:6.47819
# [103]	validation-rmse:6.47742
# [104]	validation-rmse:6.47685
# [105]	validation-rmse:6.47643
# [106]	validation-rmse:6.47616
# [107]	validation-rmse:6.47583
# [108]	validation-rmse:6.47530
# [109]	validation-rmse:6.47479
# [110]	validation-rmse:6.47409
# [111]	validation-rmse:6.47339
# [112]	validation-rmse:6.47296
# [113]	validation-rmse:6.47250
# [114]	validation-rmse:6.47148
# [115]	validation-rmse:6.47089
# [116]	validation-rmse:6.47037
# [117]	validation-rmse:6.46947
# [118]	validation-rmse:6.46907
# [119]	validation-rmse:6.46840
# [120]	validation-rmse:6.46749
# [121]	validation-rmse:6.46701
# [122]	validation-rmse:6.46612
# [123]	validation-rmse:6.46538
# [124]	validation-rmse:6.46467
# [125]	validation-rmse:6.46413
# [126]	validation-rmse:6.46350
# [127]	validation-rmse:6.46265
# [128]	validation-rmse:6.46225
# [129]	validation-rmse:6.46169
# [130]	validation-rmse:6.46065
# [131]	validation-rmse:6.46022
# [132]	validation-rmse:6.45980
# [133]	validation-rmse:6.45918
# [134]	validation-rmse:6.45844
# [135]	validation-rmse:6.45802
# [136]	validation-rmse:6.45783
# [137]	validation-rmse:6.45746
# [138]	validation-rmse:6.45661
# [139]	validation-rmse:6.45619
# [140]	validation-rmse:6.45566
# [141]	validation-rmse:6.45554
# [142]	validation-rmse:6.45487
# [143]	validation-rmse:6.45461
# [144]	validation-rmse:6.45411
# [145]	validation-rmse:6.45325
# [146]	validation-rmse:6.45278
# [147]	validation-rmse:6.45215
# [148]	validation-rmse:6.45174
# [149]	validation-rmse:6.45146
# [150]	validation-rmse:6.45113
# [151]	validation-rmse:6.45076
# [152]	validation-rmse:6.45012
# [153]	validation-rmse:6.44965
# [154]	validation-rmse:6.44905
# [155]	validation-rmse:6.44872
# [156]	validation-rmse:6.44825
# [157]	validation-rmse:6.44792
# [158]	validation-rmse:6.44743
# [159]	validation-rmse:6.44671
# [160]	validation-rmse:6.44616
# [161]	validation-rmse:6.44562
# [162]	validation-rmse:6.44503
# [163]	validation-rmse:6.44434
# [164]	validation-rmse:6.44399
# [165]	validation-rmse:6.44339
# [166]	validation-rmse:6.44303
# [167]	validation-rmse:6.44260
# [168]	validation-rmse:6.44207
# [169]	validation-rmse:6.44173
# [170]	validation-rmse:6.44107
# [171]	validation-rmse:6.44068
# [172]	validation-rmse:6.44007
# [173]	validation-rmse:6.43964
# [174]	validation-rmse:6.43918
# [175]	validation-rmse:6.43883
# [176]	validation-rmse:6.43842
# [177]	validation-rmse:6.43803
# [178]	validation-rmse:6.43759
# [179]	validation-rmse:6.43714
# [180]	validation-rmse:6.43676
# [181]	validation-rmse:6.43644
# [182]	validation-rmse:6.43605
# [183]	validation-rmse:6.43571
# [184]	validation-rmse:6.43527
# [185]	validation-rmse:6.43489
# [186]	validation-rmse:6.43435
# [187]	validation-rmse:6.43408
# [188]	validation-rmse:6.43376
# [189]	validation-rmse:6.43360
# [190]	validation-rmse:6.43347
# [191]	validation-rmse:6.43343
# [192]	validation-rmse:6.43284
# [193]	validation-rmse:6.43259
# [194]	validation-rmse:6.43222
# [195]	validation-rmse:6.43187
# [196]	validation-rmse:6.43157
# [197]	validation-rmse:6.43102
# [198]	validation-rmse:6.43084
# [199]	validation-rmse:6.43085
# [200]	validation-rmse:6.43072
# [201]	validation-rmse:6.43048
# [202]	validation-rmse:6.43004
# [203]	validation-rmse:6.42961
# [204]	validation-rmse:6.42896
# [205]	validation-rmse:6.42861
# [206]	validation-rmse:6.42831
# [207]	validation-rmse:6.42808
# [208]	validation-rmse:6.42801
# [209]	validation-rmse:6.42755
# [210]	validation-rmse:6.42700
# [211]	validation-rmse:6.42653
# [212]	validation-rmse:6.42617
# [213]	validation-rmse:6.42564
# [214]	validation-rmse:6.42532
# [215]	validation-rmse:6.42478
# [216]	validation-rmse:6.42448
# [217]	validation-rmse:6.42402
# [218]	validation-rmse:6.42359
# [219]	validation-rmse:6.42338
# [220]	validation-rmse:6.42298
# [221]	validation-rmse:6.42271
# [222]	validation-rmse:6.42247
# [223]	validation-rmse:6.42197
# [224]	validation-rmse:6.42171
# [225]	validation-rmse:6.42122
# [226]	validation-rmse:6.42061
# [227]	validation-rmse:6.42051
# [228]	validation-rmse:6.42004
# [229]	validation-rmse:6.41970
# [230]	validation-rmse:6.41931
# [231]	validation-rmse:6.41891
# [232]	validation-rmse:6.41880
# [233]	validation-rmse:6.41871
# [234]	validation-rmse:6.41846
# [235]	validation-rmse:6.41782
# [236]	validation-rmse:6.41750
# [237]	validation-rmse:6.41718
# [238]	validation-rmse:6.41680
# [239]	validation-rmse:6.41642
# [240]	validation-rmse:6.41611
# [241]	validation-rmse:6.41599
# [242]	validation-rmse:6.41567
# [243]	validation-rmse:6.41528
# [244]	validation-rmse:6.41504
# [245]	validation-rmse:6.41465
# [246]	validation-rmse:6.41431
# [247]	validation-rmse:6.41400
# [248]	validation-rmse:6.41364
# [249]	validation-rmse:6.41342
# [250]	validation-rmse:6.41328
# [251]	validation-rmse:6.41325
# [252]	validation-rmse:6.41308
# [253]	validation-rmse:6.41279
# [254]	validation-rmse:6.41259
# [255]	validation-rmse:6.41198
# [256]	validation-rmse:6.41179
# [257]	validation-rmse:6.41155
# [258]	validation-rmse:6.41131
# [259]	validation-rmse:6.41075
# [260]	validation-rmse:6.41055
# [261]	validation-rmse:6.41016
# [262]	validation-rmse:6.41002
# [263]	validation-rmse:6.41006
# [264]	validation-rmse:6.40985
# [265]	validation-rmse:6.40970
# [266]	validation-rmse:6.40951
# [267]	validation-rmse:6.40926
# [268]	validation-rmse:6.40903
# [269]	validation-rmse:6.40865
# [270]	validation-rmse:6.40830
# [271]	validation-rmse:6.40805
# [272]	validation-rmse:6.40790
# [273]	validation-rmse:6.40767
# [274]	validation-rmse:6.40749
# [275]	validation-rmse:6.40734
# [276]	validation-rmse:6.40696
# [277]	validation-rmse:6.40666
# [278]	validation-rmse:6.40632
# [279]	validation-rmse:6.40581
# [280]	validation-rmse:6.40552
# [281]	validation-rmse:6.40505
# [282]	validation-rmse:6.40472
# [283]	validation-rmse:6.40449
# [284]	validation-rmse:6.40420
# [285]	validation-rmse:6.40377
# [286]	validation-rmse:6.40347
# [287]	validation-rmse:6.40305
# [288]	validation-rmse:6.40283
# [289]	validation-rmse:6.40268
# [290]	validation-rmse:6.40245
# [291]	validation-rmse:6.40219
# [292]	validation-rmse:6.40207
# [293]	validation-rmse:6.40178
# [294]	validation-rmse:6.40135
# [295]	validation-rmse:6.40101
# [296]	validation-rmse:6.40064
# [297]	validation-rmse:6.40041
# [298]	validation-rmse:6.40004
# [299]	validation-rmse:6.39995
# [300]	validation-rmse:6.39958
# [301]	validation-rmse:6.39939
# [302]	validation-rmse:6.39900
# [303]	validation-rmse:6.39883
# [304]	validation-rmse:6.39869
# [305]	validation-rmse:6.39846
# [306]	validation-rmse:6.39837
# [307]	validation-rmse:6.39819
# [308]	validation-rmse:6.39793
# [309]	validation-rmse:6.39771
# [310]	validation-rmse:6.39720
# [311]	validation-rmse:6.39687
# [312]	validation-rmse:6.39660
# [313]	validation-rmse:6.39603
# [314]	validation-rmse:6.39590
# [315]	validation-rmse:6.39579
# [316]	validation-rmse:6.39557
# [317]	validation-rmse:6.39519
# [318]	validation-rmse:6.39501
# [319]	validation-rmse:6.39472
# [320]	validation-rmse:6.39456
# [321]	validation-rmse:6.39437
# [322]	validation-rmse:6.39419
# [323]	validation-rmse:6.39385
# [324]	validation-rmse:6.39350
# [325]	validation-rmse:6.39331
# [326]	validation-rmse:6.39326
# [327]	validation-rmse:6.39311
# [328]	validation-rmse:6.39315
# [329]	validation-rmse:6.39302
# [330]	validation-rmse:6.39281
# [331]	validation-rmse:6.39274
# [332]	validation-rmse:6.39254
# [333]	validation-rmse:6.39242
# [334]	validation-rmse:6.39193
# [335]	validation-rmse:6.39169
# [336]	validation-rmse:6.39148
# [337]	validation-rmse:6.39136
# [338]	validation-rmse:6.39108
# [339]	validation-rmse:6.39103
# [340]	validation-rmse:6.39079
# [341]	validation-rmse:6.39058
# [342]	validation-rmse:6.39045
# [343]	validation-rmse:6.39022
# [344]	validation-rmse:6.39024
# [345]	validation-rmse:6.39007
# [346]	validation-rmse:6.39002
# [347]	validation-rmse:6.38999
# [348]	validation-rmse:6.38977
# [349]	validation-rmse:6.38951
# [350]	validation-rmse:6.38951
# [351]	validation-rmse:6.38944
# [352]	validation-rmse:6.38923
# [353]	validation-rmse:6.38903
# [354]	validation-rmse:6.38885
# [355]	validation-rmse:6.38867
# [356]	validation-rmse:6.38856
# [357]	validation-rmse:6.38845
# [358]	validation-rmse:6.38818
# [359]	validation-rmse:6.38787
# [360]	validation-rmse:6.38751
# [361]	validation-rmse:6.38704
# [362]	validation-rmse:6.38673
# [363]	validation-rmse:6.38648
# [364]	validation-rmse:6.38626
# [365]	validation-rmse:6.38610
# [366]	validation-rmse:6.38573
# [367]	validation-rmse:6.38525
# [368]	validation-rmse:6.38505
# [369]	validation-rmse:6.38483
# [370]	validation-rmse:6.38457
# [371]	validation-rmse:6.38450
# [372]	validation-rmse:6.38420
# [373]	validation-rmse:6.38398
# [374]	validation-rmse:6.38392
# [375]	validation-rmse:6.38368
# [376]	validation-rmse:6.38342
# [377]	validation-rmse:6.38321
# [378]	validation-rmse:6.38318
# [379]	validation-rmse:6.38285
# [380]	validation-rmse:6.38258
# [381]	validation-rmse:6.38225
# [382]	validation-rmse:6.38211
# [383]	validation-rmse:6.38171
# [384]	validation-rmse:6.38155
# [385]	validation-rmse:6.38138
# [386]	validation-rmse:6.38110
# [387]	validation-rmse:6.38089
# [388]	validation-rmse:6.38071
# [389]	validation-rmse:6.38059
# [390]	validation-rmse:6.38023
# [391]	validation-rmse:6.38004
# [392]	validation-rmse:6.37982
# [393]	validation-rmse:6.37962
# [394]	validation-rmse:6.37968
# [395]	validation-rmse:6.37956
# [396]	validation-rmse:6.37937
# [397]	validation-rmse:6.37885
# [398]	validation-rmse:6.37864
# [399]	validation-rmse:6.37815
# [400]	validation-rmse:6.37803
# [401]	validation-rmse:6.37778
# [402]	validation-rmse:6.37749
# [403]	validation-rmse:6.37731
# [404]	validation-rmse:6.37712
# [405]	validation-rmse:6.37698
# [406]	validation-rmse:6.37677
# [407]	validation-rmse:6.37658
# [408]	validation-rmse:6.37647
# [409]	validation-rmse:6.37631
# [410]	validation-rmse:6.37617
# [411]	validation-rmse:6.37575
# [412]	validation-rmse:6.37566
# [413]	validation-rmse:6.37556
# [414]	validation-rmse:6.37533
# [415]	validation-rmse:6.37538
# [416]	validation-rmse:6.37541
# [417]	validation-rmse:6.37530
# [418]	validation-rmse:6.37511
# [419]	validation-rmse:6.37512
# [420]	validation-rmse:6.37496
# [421]	validation-rmse:6.37483
# [422]	validation-rmse:6.37478
# [423]	validation-rmse:6.37466
# [424]	validation-rmse:6.37440
# [425]	validation-rmse:6.37416
# [426]	validation-rmse:6.37387
# [427]	validation-rmse:6.37384
# [428]	validation-rmse:6.37367
# [429]	validation-rmse:6.37357
# [430]	validation-rmse:6.37345
# [431]	validation-rmse:6.37330
# [432]	validation-rmse:6.37293
# [433]	validation-rmse:6.37265
# [434]	validation-rmse:6.37245
# [435]	validation-rmse:6.37236
# [436]	validation-rmse:6.37233
# [437]	validation-rmse:6.37222
# [438]	validation-rmse:6.37221
# [439]	validation-rmse:6.37218
# [440]	validation-rmse:6.37198
# [441]	validation-rmse:6.37195
# [442]	validation-rmse:6.37190
# [443]	validation-rmse:6.37189
# [444]	validation-rmse:6.37171
# [445]	validation-rmse:6.37159
# [446]	validation-rmse:6.37148
# [447]	validation-rmse:6.37152
# [448]	validation-rmse:6.37128
# [449]	validation-rmse:6.37125
# [450]	validation-rmse:6.37110
# [451]	validation-rmse:6.37086
# [452]	validation-rmse:6.37067
# [453]	validation-rmse:6.37035
# [454]	validation-rmse:6.37019
# [455]	validation-rmse:6.36995
# [456]	validation-rmse:6.36964
# [457]	validation-rmse:6.36935
# [458]	validation-rmse:6.36895
# [459]	validation-rmse:6.36883
# [460]	validation-rmse:6.36862
# [461]	validation-rmse:6.36842
# [462]	validation-rmse:6.36826
# [463]	validation-rmse:6.36789
# [464]	validation-rmse:6.36769
# [465]	validation-rmse:6.36769
# [466]	validation-rmse:6.36764
# [467]	validation-rmse:6.36735
# [468]	validation-rmse:6.36717
# [469]	validation-rmse:6.36706
# [470]	validation-rmse:6.36690
# [471]	validation-rmse:6.36676
# [472]	validation-rmse:6.36671
# [473]	validation-rmse:6.36656
# [474]	validation-rmse:6.36627
# [475]	validation-rmse:6.36626
# [476]	validation-rmse:6.36614
# [477]	validation-rmse:6.36595
# [478]	validation-rmse:6.36597
# [479]	validation-rmse:6.36584
# [480]	validation-rmse:6.36566
# [481]	validation-rmse:6.36531
# [482]	validation-rmse:6.36523
# [483]	validation-rmse:6.36517
# [484]	validation-rmse:6.36487
# [485]	validation-rmse:6.36472
# [486]	validation-rmse:6.36459
# [487]	validation-rmse:6.36439
# [488]	validation-rmse:6.36424
# [489]	validation-rmse:6.36401
# [490]	validation-rmse:6.36386
# [491]	validation-rmse:6.36369
# [492]	validation-rmse:6.36348
# [493]	validation-rmse:6.36316
# [494]	validation-rmse:6.36311
# [495]	validation-rmse:6.36313
# [496]	validation-rmse:6.36295
# [497]	validation-rmse:6.36292
# [498]	validation-rmse:6.36283
# [499]	validation-rmse:6.36268
# [500]	validation-rmse:6.36237
# [501]	validation-rmse:6.36220
# [502]	validation-rmse:6.36207
# [503]	validation-rmse:6.36177
# [504]	validation-rmse:6.36172
# [505]	validation-rmse:6.36153
# [506]	validation-rmse:6.36143
# [507]	validation-rmse:6.36129
# [508]	validation-rmse:6.36116
# [509]	validation-rmse:6.36092
# [510]	validation-rmse:6.36073
# [511]	validation-rmse:6.36044
# [512]	validation-rmse:6.36036
# [513]	validation-rmse:6.36024
# [514]	validation-rmse:6.36008
# [515]	validation-rmse:6.36008
# [516]	validation-rmse:6.35995
# [517]	validation-rmse:6.36001
# [518]	validation-rmse:6.35985
# [519]	validation-rmse:6.35968
# [520]	validation-rmse:6.35961
# [521]	validation-rmse:6.35962
# [522]	validation-rmse:6.35963
# [523]	validation-rmse:6.35945
# [524]	validation-rmse:6.35932
# [525]	validation-rmse:6.35923
# [526]	validation-rmse:6.35909
# [527]	validation-rmse:6.35908
# [528]	validation-rmse:6.35911
# [529]	validation-rmse:6.35892
# [530]	validation-rmse:6.35873
# [531]	validation-rmse:6.35860
# [532]	validation-rmse:6.35828
# [533]	validation-rmse:6.35824
# [534]	validation-rmse:6.35805
# [535]	validation-rmse:6.35791
# [536]	validation-rmse:6.35774
# [537]	validation-rmse:6.35752
# [538]	validation-rmse:6.35727
# [539]	validation-rmse:6.35711
# [540]	validation-rmse:6.35700
# [541]	validation-rmse:6.35692
# [542]	validation-rmse:6.35679
# [543]	validation-rmse:6.35677
# [544]	validation-rmse:6.35678
# [545]	validation-rmse:6.35676
# [546]	validation-rmse:6.35671
# [547]	validation-rmse:6.35666
# [548]	validation-rmse:6.35675
# [549]	validation-rmse:6.35666
# [550]	validation-rmse:6.35656
# [551]	validation-rmse:6.35636
# [552]	validation-rmse:6.35630
# [553]	validation-rmse:6.35613
# [554]	validation-rmse:6.35621
# [555]	validation-rmse:6.35604
# [556]	validation-rmse:6.35586
# [557]	validation-rmse:6.35563
# [558]	validation-rmse:6.35564
# [559]	validation-rmse:6.35548
# [560]	validation-rmse:6.35528
# [561]	validation-rmse:6.35488
# [562]	validation-rmse:6.35475
# [563]	validation-rmse:6.35457
# [564]	validation-rmse:6.35443
# [565]	validation-rmse:6.35436
# [566]	validation-rmse:6.35431
# [567]	validation-rmse:6.35407
# [568]	validation-rmse:6.35379
# [569]	validation-rmse:6.35378
# [570]	validation-rmse:6.35371
# [571]	validation-rmse:6.35347
# [572]	validation-rmse:6.35313
# [573]	validation-rmse:6.35301
# [574]	validation-rmse:6.35292
# [575]	validation-rmse:6.35259
# [576]	validation-rmse:6.35244
# [577]	validation-rmse:6.35232
# [578]	validation-rmse:6.35216
# [579]	validation-rmse:6.35197
# [580]	validation-rmse:6.35184
# [581]	validation-rmse:6.35171
# [582]	validation-rmse:6.35158
# [583]	validation-rmse:6.35155
# [584]	validation-rmse:6.35141
# [585]	validation-rmse:6.35150
# [586]	validation-rmse:6.35138
# [587]	validation-rmse:6.35135
# [588]	validation-rmse:6.35117
# [589]	validation-rmse:6.35092
# [590]	validation-rmse:6.35080
# [591]	validation-rmse:6.35072
# [592]	validation-rmse:6.35060
# [593]	validation-rmse:6.35054
# [594]	validation-rmse:6.35044
# [595]	validation-rmse:6.35023
# [596]	validation-rmse:6.35024
# [597]	validation-rmse:6.35010
# [598]	validation-rmse:6.34977
# [599]	validation-rmse:6.34970
# [600]	validation-rmse:6.34944
# [601]	validation-rmse:6.34945
# [602]	validation-rmse:6.34938
# [603]	validation-rmse:6.34915
# [604]	validation-rmse:6.34891
# [605]	validation-rmse:6.34870
# [606]	validation-rmse:6.34850
# [607]	validation-rmse:6.34852
# [608]	validation-rmse:6.34834
# [609]	validation-rmse:6.34821
# [610]	validation-rmse:6.34807
# [611]	validation-rmse:6.34796
# [612]	validation-rmse:6.34790
# [613]	validation-rmse:6.34777
# [614]	validation-rmse:6.34769
# [615]	validation-rmse:6.34750
# [616]	validation-rmse:6.34707
# [617]	validation-rmse:6.34703
# [618]	validation-rmse:6.34698
# [619]	validation-rmse:6.34688
# [620]	validation-rmse:6.34668
# [621]	validation-rmse:6.34654
# [622]	validation-rmse:6.34654
# [623]	validation-rmse:6.34648
# [624]	validation-rmse:6.34656
# [625]	validation-rmse:6.34648
# [626]	validation-rmse:6.34634
# [627]	validation-rmse:6.34633
# [628]	validation-rmse:6.34629
# [629]	validation-rmse:6.34613
# [630]	validation-rmse:6.34611
# [631]	validation-rmse:6.34605
# [632]	validation-rmse:6.34591
# [633]	validation-rmse:6.34579
# [634]	validation-rmse:6.34573
# [635]	validation-rmse:6.34559
# [636]	validation-rmse:6.34558
# [637]	validation-rmse:6.34557
# [638]	validation-rmse:6.34547
# [639]	validation-rmse:6.34545
# [640]	validation-rmse:6.34505
# [641]	validation-rmse:6.34506
# [642]	validation-rmse:6.34503
# [643]	validation-rmse:6.34500
# [644]	validation-rmse:6.34477
# [645]	validation-rmse:6.34472
# [646]	validation-rmse:6.34472
# [647]	validation-rmse:6.34473
# [648]	validation-rmse:6.34462
# [649]	validation-rmse:6.34442
# [650]	validation-rmse:6.34423
# [651]	validation-rmse:6.34426
# [652]	validation-rmse:6.34401
# [653]	validation-rmse:6.34393
# [654]	validation-rmse:6.34376
# [655]	validation-rmse:6.34378
# [656]	validation-rmse:6.34363
# [657]	validation-rmse:6.34356
# [658]	validation-rmse:6.34328
# [659]	validation-rmse:6.34325
# [660]	validation-rmse:6.34311
# [661]	validation-rmse:6.34303
# [662]	validation-rmse:6.34303
# [663]	validation-rmse:6.34293
# [664]	validation-rmse:6.34310
# [665]	validation-rmse:6.34289
# [666]	validation-rmse:6.34279
# [667]	validation-rmse:6.34269
# [668]	validation-rmse:6.34260
# [669]	validation-rmse:6.34238
# [670]	validation-rmse:6.34223
# [671]	validation-rmse:6.34210
# [672]	validation-rmse:6.34207
# [673]	validation-rmse:6.34201
# [674]	validation-rmse:6.34192
# [675]	validation-rmse:6.34207
# [676]	validation-rmse:6.34191
# [677]	validation-rmse:6.34197
# [678]	validation-rmse:6.34185
# [679]	validation-rmse:6.34168
# [680]	validation-rmse:6.34158
# [681]	validation-rmse:6.34146
# [682]	validation-rmse:6.34140
# [683]	validation-rmse:6.34138
# [684]	validation-rmse:6.34125
# [685]	validation-rmse:6.34119
# [686]	validation-rmse:6.34118
# [687]	validation-rmse:6.34103
# [688]	validation-rmse:6.34101
# [689]	validation-rmse:6.34087
# [690]	validation-rmse:6.34075
# [691]	validation-rmse:6.34056
# [692]	validation-rmse:6.34040
# [693]	validation-rmse:6.34015
# [694]	validation-rmse:6.34005
# [695]	validation-rmse:6.33987
# [696]	validation-rmse:6.33983
# [697]	validation-rmse:6.33979
# [698]	validation-rmse:6.33971
# [699]	validation-rmse:6.33974
# [700]	validation-rmse:6.33952
# [701]	validation-rmse:6.33946
# [702]	validation-rmse:6.33958
# [703]	validation-rmse:6.33951
# [704]	validation-rmse:6.33946
# [705]	validation-rmse:6.33930
# [706]	validation-rmse:6.33904
# [707]	validation-rmse:6.33908
# [708]	validation-rmse:6.33892
# [709]	validation-rmse:6.33888
# [710]	validation-rmse:6.33870
# [711]	validation-rmse:6.33861
# [712]	validation-rmse:6.33847
# [713]	validation-rmse:6.33842
# [714]	validation-rmse:6.33833
# [715]	validation-rmse:6.33822
# [716]	validation-rmse:6.33830
# [717]	validation-rmse:6.33819
# [718]	validation-rmse:6.33814
# [719]	validation-rmse:6.33802
# [720]	validation-rmse:6.33802
# [721]	validation-rmse:6.33787
# [722]	validation-rmse:6.33773
# [723]	validation-rmse:6.33754
# [724]	validation-rmse:6.33732
# [725]	validation-rmse:6.33714
# [726]	validation-rmse:6.33689
# [727]	validation-rmse:6.33675
# [728]	validation-rmse:6.33656
# [729]	validation-rmse:6.33647
# [730]	validation-rmse:6.33638
# [731]	validation-rmse:6.33636
# [732]	validation-rmse:6.33618
# [733]	validation-rmse:6.33607
# [734]	validation-rmse:6.33600
# [735]	validation-rmse:6.33595
# [736]	validation-rmse:6.33595
# [737]	validation-rmse:6.33591
# [738]	validation-rmse:6.33585
# [739]	validation-rmse:6.33559
# [740]	validation-rmse:6.33557
# [741]	validation-rmse:6.33540
# [742]	validation-rmse:6.33534
# [743]	validation-rmse:6.33540
# [744]	validation-rmse:6.33526
# [745]	validation-rmse:6.33518
# [746]	validation-rmse:6.33513
# [747]	validation-rmse:6.33514
# [748]	validation-rmse:6.33508
# [749]	validation-rmse:6.33499
# [750]	validation-rmse:6.33497
# [751]	validation-rmse:6.33474
# [752]	validation-rmse:6.33480
# [753]	validation-rmse:6.33486
# [754]	validation-rmse:6.33465
# [755]	validation-rmse:6.33461
# [756]	validation-rmse:6.33457
# [757]	validation-rmse:6.33448
# [758]	validation-rmse:6.33445
# [759]	validation-rmse:6.33440
# [760]	validation-rmse:6.33427
# [761]	validation-rmse:6.33406
# [762]	validation-rmse:6.33400
# [763]	validation-rmse:6.33401
# [764]	validation-rmse:6.33395
# [765]	validation-rmse:6.33388
# [766]	validation-rmse:6.33372
# [767]	validation-rmse:6.33379
# [768]	validation-rmse:6.33383
# [769]	validation-rmse:6.33372
# [770]	validation-rmse:6.33365
# [771]	validation-rmse:6.33366
# [772]	validation-rmse:6.33365
# [773]	validation-rmse:6.33364
# [774]	validation-rmse:6.33363
# [775]	validation-rmse:6.33350
# [776]	validation-rmse:6.33317
# [777]	validation-rmse:6.33316
# [778]	validation-rmse:6.33307
# [779]	validation-rmse:6.33306
# [780]	validation-rmse:6.33279
# [781]	validation-rmse:6.33267
# [782]	validation-rmse:6.33249
# [783]	validation-rmse:6.33235
# [784]	validation-rmse:6.33204
# [785]	validation-rmse:6.33197
# [786]	validation-rmse:6.33194
# [787]	validation-rmse:6.33177
# [788]	validation-rmse:6.33186
# [789]	validation-rmse:6.33172
# [790]	validation-rmse:6.33167
# [791]	validation-rmse:6.33159
# [792]	validation-rmse:6.33160
# [793]	validation-rmse:6.33168
# [794]	validation-rmse:6.33172
# [795]	validation-rmse:6.33154
# [796]	validation-rmse:6.33146
# [797]	validation-rmse:6.33128
# [798]	validation-rmse:6.33118
# [799]	validation-rmse:6.33111
# [800]	validation-rmse:6.33117
# [801]	validation-rmse:6.33116
# [802]	validation-rmse:6.33095
# [803]	validation-rmse:6.33097
# [804]	validation-rmse:6.33101
# [805]	validation-rmse:6.33097
# [806]	validation-rmse:6.33088
# [807]	validation-rmse:6.33089
# [808]	validation-rmse:6.33091
# [809]	validation-rmse:6.33092
# [810]	validation-rmse:6.33079
# [811]	validation-rmse:6.33072
# [812]	validation-rmse:6.33076
# [813]	validation-rmse:6.33066
# [814]	validation-rmse:6.33062
# [815]	validation-rmse:6.33050
# [816]	validation-rmse:6.33026
# [817]	validation-rmse:6.33024
# [818]	validation-rmse:6.33027
# [819]	validation-rmse:6.33023
# [820]	validation-rmse:6.33019
# [821]	validation-rmse:6.33007
# [822]	validation-rmse:6.32995
# [823]	validation-rmse:6.32997
# [824]	validation-rmse:6.32989
# [825]	validation-rmse:6.32990
# [826]	validation-rmse:6.32972
# [827]	validation-rmse:6.32970
# [828]	validation-rmse:6.32958
# [829]	validation-rmse:6.32960
# [830]	validation-rmse:6.32935
# [831]	validation-rmse:6.32935
# [832]	validation-rmse:6.32924
# [833]	validation-rmse:6.32914
# [834]	validation-rmse:6.32909
# [835]	validation-rmse:6.32881
# [836]	validation-rmse:6.32883
# [837]	validation-rmse:6.32881
# [838]	validation-rmse:6.32873
# [839]	validation-rmse:6.32861
# [840]	validation-rmse:6.32864
# [841]	validation-rmse:6.32855
# [842]	validation-rmse:6.32851
# [843]	validation-rmse:6.32846
# [844]	validation-rmse:6.32829
# [845]	validation-rmse:6.32817
# [846]	validation-rmse:6.32795
# [847]	validation-rmse:6.32786
# [848]	validation-rmse:6.32772
# [849]	validation-rmse:6.32758
# [850]	validation-rmse:6.32751
# [851]	validation-rmse:6.32749
# [852]	validation-rmse:6.32739
# [853]	validation-rmse:6.32729
# [854]	validation-rmse:6.32725
# [855]	validation-rmse:6.32729
# [856]	validation-rmse:6.32718
# [857]	validation-rmse:6.32688
# [858]	validation-rmse:6.32680
# [859]	validation-rmse:6.32676
# [860]	validation-rmse:6.32663
# [861]	validation-rmse:6.32637
# [862]	validation-rmse:6.32633
# [863]	validation-rmse:6.32626
# [864]	validation-rmse:6.32634
# [865]	validation-rmse:6.32645
# [866]	validation-rmse:6.32627
# [867]	validation-rmse:6.32618
# [868]	validation-rmse:6.32603
# [869]	validation-rmse:6.32574
# [870]	validation-rmse:6.32571
# [871]	validation-rmse:6.32574
# [872]	validation-rmse:6.32589
# [873]	validation-rmse:6.32584
# [874]	validation-rmse:6.32579
# [875]	validation-rmse:6.32573
# [876]	validation-rmse:6.32547
# [877]	validation-rmse:6.32546
# [878]	validation-rmse:6.32552
# [879]	validation-rmse:6.32545
# [880]	validation-rmse:6.32552
# [881]	validation-rmse:6.32532
# [882]	validation-rmse:6.32527
# [883]	validation-rmse:6.32525
# [884]	validation-rmse:6.32520
# [885]	validation-rmse:6.32506
# [886]	validation-rmse:6.32466
# [887]	validation-rmse:6.32466
# [888]	validation-rmse:6.32470
# [889]	validation-rmse:6.32461
# [890]	validation-rmse:6.32450
# [891]	validation-rmse:6.32444
# [892]	validation-rmse:6.32432
# [893]	validation-rmse:6.32420
# [894]	validation-rmse:6.32408
# [895]	validation-rmse:6.32403
# [896]	validation-rmse:6.32392
# [897]	validation-rmse:6.32379
# [898]	validation-rmse:6.32383
# [899]	validation-rmse:6.32379
# [900]	validation-rmse:6.32371
# [901]	validation-rmse:6.32332
# [902]	validation-rmse:6.32334
# [903]	validation-rmse:6.32343
# [904]	validation-rmse:6.32333
# [905]	validation-rmse:6.32333
# [906]	validation-rmse:6.32335
# [907]	validation-rmse:6.32332
# [908]	validation-rmse:6.32329
# [909]	validation-rmse:6.32330
# [910]	validation-rmse:6.32319
# [911]	validation-rmse:6.32313
# [912]	validation-rmse:6.32315
# [913]	validation-rmse:6.32306
# [914]	validation-rmse:6.32299
# [915]	validation-rmse:6.32289
# [916]	validation-rmse:6.32287
# [917]	validation-rmse:6.32273
# [918]	validation-rmse:6.32267
# [919]	validation-rmse:6.32259
# [920]	validation-rmse:6.32237
# [921]	validation-rmse:6.32216
# [922]	validation-rmse:6.32213
# [923]	validation-rmse:6.32221
# [924]	validation-rmse:6.32206
# [925]	validation-rmse:6.32204
# [926]	validation-rmse:6.32193
# [927]	validation-rmse:6.32191
# [928]	validation-rmse:6.32170
# [929]	validation-rmse:6.32149
# [930]	validation-rmse:6.32156
# [931]	validation-rmse:6.32149
# [932]	validation-rmse:6.32146
# [933]	validation-rmse:6.32152
# [934]	validation-rmse:6.32135
# [935]	validation-rmse:6.32131
# [936]	validation-rmse:6.32133
# [937]	validation-rmse:6.32130
# [938]	validation-rmse:6.32129
# [939]	validation-rmse:6.32120
# [940]	validation-rmse:6.32104
# [941]	validation-rmse:6.32097
# [942]	validation-rmse:6.32088
# [943]	validation-rmse:6.32082
# [944]	validation-rmse:6.32089
# [945]	validation-rmse:6.32102
# [946]	validation-rmse:6.32074
# [947]	validation-rmse:6.32082
# [948]	validation-rmse:6.32074
# [949]	validation-rmse:6.32066
# [950]	validation-rmse:6.32043
# [951]	validation-rmse:6.32020
# [952]	validation-rmse:6.32007
# [953]	validation-rmse:6.32009
# [954]	validation-rmse:6.32009
# [955]	validation-rmse:6.32004
# [956]	validation-rmse:6.32001
# [957]	validation-rmse:6.31998
# [958]	validation-rmse:6.31987
# [959]	validation-rmse:6.31992
# [960]	validation-rmse:6.31981
# [961]	validation-rmse:6.31981
# [962]	validation-rmse:6.31983
# [963]	validation-rmse:6.31978
# [964]	validation-rmse:6.31960
# [965]	validation-rmse:6.31961
# [966]	validation-rmse:6.31958
# [967]	validation-rmse:6.31948
# [968]	validation-rmse:6.31946
# [969]	validation-rmse:6.31950
# [970]	validation-rmse:6.31951
# [971]	validation-rmse:6.31957
# [972]	validation-rmse:6.31957
# [973]	validation-rmse:6.31959
# [974]	validation-rmse:6.31942
# [975]	validation-rmse:6.31937
# [976]	validation-rmse:6.31937
# [977]	validation-rmse:6.31927
# [978]	validation-rmse:6.31919
# [979]	validation-rmse:6.31919
# [980]	validation-rmse:6.31907
# [981]	validation-rmse:6.31907
# [982]	validation-rmse:6.31898
# [983]	validation-rmse:6.31904
# [984]	validation-rmse:6.31907
# [985]	validation-rmse:6.31894
# [986]	validation-rmse:6.31894
# [987]	validation-rmse:6.31893
# [988]	validation-rmse:6.31877
# [989]	validation-rmse:6.31896
# [990]	validation-rmse:6.31893
# [991]	validation-rmse:6.31875
# [992]	validation-rmse:6.31862
# [993]	validation-rmse:6.31853
# [994]	validation-rmse:6.31855
# [995]	validation-rmse:6.31848
# [996]	validation-rmse:6.31855
# [997]	validation-rmse:6.31850
# [998]	validation-rmse:6.31857
# [999]	validation-rmse:6.31845
# /Users/weishanhe/opt/miniconda3/envs/mlops/lib/python3.9/site-packages/sklearn/metrics/_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Users/weishanhe/opt/miniconda3/envs/mlops/lib/python3.9/site-packages/xgboost/core.py:160: UserWarning: [22:04:57] WARNING: /Users/runner/work/xgboost/xgboost/src/c_api/c_api.cc:1240: Saving into deprecated binary model format, please consider using `json` or `ubj`. Model format will default to JSON in XGBoost 2.2 if not specified.
#   warnings.warn(smsg, UserWarning)

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor
from sklearn.svm import LinearSVR

mlflow.sklearn.autolog()

for model_class in (RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor, LinearSVR):

    with mlflow.start_run():

        mlflow.log_param("train-data-path", "./data/green_tripdata_2021-01.csv")
        mlflow.log_param("valid-data-path", "./data/green_tripdata_2021-02.csv")
        mlflow.log_artifact("models/preprocessor.b", artifact_path="preprocessor")

        mlmodel = model_class()
        mlmodel.fit(X_train, y_train)

        y_pred = mlmodel.predict(X_val)
        rmse = mean_squared_error(y_val, y_pred, squared=False)
        mlflow.log_metric("rmse", rmse)
# Out:
# /Users/cristian.martinez/miniconda3/envs/exp-tracking-env/lib/python3.9/site-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(

# %%
logged_model = 'runs:/95a9e0645b4548f4a5bac4a30539a699/models_mlflow'

# Load model as a PyFuncModel.
loaded_model = mlflow.pyfunc.load_model(logged_model)
# Out:
# /Users/weishanhe/opt/miniconda3/envs/mlops/lib/python3.9/site-packages/xgboost/core.py:160: UserWarning: [22:12:18] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)

# %%
loaded_model
# Out:
# mlflow.pyfunc.loaded_model:
#   artifact_path: models_mlflow
#   flavor: mlflow.xgboost
#   run_id: 95a9e0645b4548f4a5bac4a30539a699

# %%
xgboost_model = mlflow.xgboost.load_model(logged_model)
# Out:
# /Users/weishanhe/opt/miniconda3/envs/mlops/lib/python3.9/site-packages/xgboost/core.py:160: UserWarning: [22:13:39] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)

# %%
xgboost_model

# %%
y_pred = xgboost_model.predict(valid)

# %%
y_pred[:10]
# Out:
# array([14.782765 ,  7.184751 , 15.971323 , 24.328938 ,  9.559302 ,
#        17.115105 , 11.6522455,  8.688133 ,  8.962229 , 18.982166 ],
#       dtype=float32)

# %%
from mlflow.tracking import MlflowClient

MLFLOW_TRACKING_URI = "sqlite:///mlflow.db"

client = MlflowClient(tracking_uri=MLFLOW_TRACKING_URI)

# %%
from mlflow.entities import ViewType

runs = client.search_runs(
    experiment_ids = '1',
    filter_string = "metrics.rmse < 6.8",
    run_view_type = ViewType.ACTIVE_ONLY,
    max_results = 5,
    order_by = ["metrics.rmse ASC"]
)

# %%
for run in runs:
    print(f"run id: {run.info.run_id}, rmse: {run.data.metrics['rmse']:.4f}")
# Out:
# run id: d786efd9650646dd8ff936eaf5b8c9fe, rmse: 6.3095
# run id: 1b235c38732f408d8864e750bc02fb11, rmse: 6.3104
# run id: aeec77ccda164cec98b0b60639db3aa5, rmse: 6.3118
# run id: b1f3eab4b34a4cb0abb1f61400eb67a1, rmse: 6.3138
# run id: 0c99ae2f785e48ee8faa877664ed11c0, rmse: 6.3144

# %%
import mlflow

mlflow.set_tracking_uri(MLFLOW_TRACKING_URI)

# %%
run_id = "d786efd9650646dd8ff936eaf5b8c9fe"
model_uri = f"runs:/{run_id}/model"
mlflow.register_model(model_uri = model_uri, name = "nyc-taxi-regressor")
# Out:
# Registered model 'nyc-taxi-regressor' already exists. Creating a new version of this model...
# Created version '3' of model 'nyc-taxi-regressor'.
# <ModelVersion: aliases=[], creation_timestamp=1716606852607, current_stage='None', description=None, last_updated_timestamp=1716606852607, name='nyc-taxi-regressor', run_id='d786efd9650646dd8ff936eaf5b8c9fe', run_link=None, source='/Users/weishanhe/my_github/mlops-zoomcamp/02-experiment-tracking/mlruns/1/d786efd9650646dd8ff936eaf5b8c9fe/artifacts/model', status='READY', status_message=None, tags={}, user_id=None, version=3>

# %%
# transition model to production
model_name = "nyc-taxi-regressor"
latest_versions = client.get_latest_versions(name = model_name)

for version in latest_versions:
    print(f"version: {version.version}, stage: {version.current_stage}")
# Out:
# version: 3, stage: None
# /var/folders/85/ncp1phfs6932692zx4c80w7c0000gn/T/ipykernel_94274/2919905036.py:3: FutureWarning: ``mlflow.tracking.client.MlflowClient.get_latest_versions`` is deprecated since 2.9.0. Model registry stages will be removed in a future major release. To learn more about the deprecation of model registry stages, see our migration guide here: https://mlflow.org/docs/2.13.0/model-registry.html#migrating-from-stages
#   latest_versions = client.get_latest_versions(name = model_name)

# %%
model_version = 3
new_stage = "Staging"
client.transition_model_version_stage(
    name = model_name,
    version = model_version,
    stage = new_stage,
    archive_existing_versions = False
)
# Out:
# /var/folders/85/ncp1phfs6932692zx4c80w7c0000gn/T/ipykernel_94274/3649399860.py:3: FutureWarning: ``mlflow.tracking.client.MlflowClient.transition_model_version_stage`` is deprecated since 2.9.0. Model registry stages will be removed in a future major release. To learn more about the deprecation of model registry stages, see our migration guide here: https://mlflow.org/docs/2.13.0/model-registry.html#migrating-from-stages
#   client.transition_model_version_stage(
# <ModelVersion: aliases=[], creation_timestamp=1716606852607, current_stage='Staging', description=None, last_updated_timestamp=1716607290565, name='nyc-taxi-regressor', run_id='d786efd9650646dd8ff936eaf5b8c9fe', run_link=None, source='/Users/weishanhe/my_github/mlops-zoomcamp/02-experiment-tracking/mlruns/1/d786efd9650646dd8ff936eaf5b8c9fe/artifacts/model', status='READY', status_message=None, tags={}, user_id=None, version=3>

# %%
from datetime import datetime
date = datetime.today().strftime('%Y-%m-%d')
client.update_model_version(
    name = model_name,
    version = 3,
    description = f"The model version {model_version} was transitioned to {new_stage} on {date}"
)
# Out:
# <ModelVersion: aliases=[], creation_timestamp=1716606852607, current_stage='Staging', description='The model version 3 was transitioned to Staging on 2024-05-24', last_updated_timestamp=1716607359386, name='nyc-taxi-regressor', run_id='d786efd9650646dd8ff936eaf5b8c9fe', run_link=None, source='/Users/weishanhe/my_github/mlops-zoomcamp/02-experiment-tracking/mlruns/1/d786efd9650646dd8ff936eaf5b8c9fe/artifacts/model', status='READY', status_message=None, tags={}, user_id=None, version=3>
